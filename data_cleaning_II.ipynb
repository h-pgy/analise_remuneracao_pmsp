# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
df = pd.read_csv('project_data/remuneracao_quadros_tecnicos.csv',
                sep=';', encoding='utf-8')

# %%
if 'Unnamed: 0' in df:
    df.drop('Unnamed: 0', axis = 1, inplace=True)

# %%
df.reset_index(drop=True,inplace=True)

# %%
df.dtypes
# Out:
# registro_funcional                   int64
# num_vinculo                          int64
# nome_servidor                       object
# dc_cargo_base                       object
# grupo_cargo_base                    object
# nivel_cargo_base                    object
# referencia_cargo_base               object
# segmento_cargo_base                 object
# dc_cargo_comissao                   object
# referencia_cargo_comissao           object
# escol_cargo_comissao                object
# relacao_juridica                    object
# qt_hora_jornada_semanal             object
# dc_orgao                            object
# dc_setor                            object
# dc_orgao_externo                    object
# qtd_servidores_orgao               float64
# dc_tipo_logradouro_orgao            object
# nm_logradouro_orgao                 object
# nr_logradouro_orgao                float64
# tx_complemento_logradouro_orgao     object
# dt_inicio_exercicio                 object
# ano_nascimento                       int64
# sexo                                object
# raca                                object
# pessoa_com_deficiencia              object
# vl_remuneracao_base_mensal          object
# vl_outro_elemento_remuneracao       object
# vl_remuneracao_total_bruta          object
# dtype: object

# %% [markdown]
# Arrumando valores de remuneracao para float

# %%
cols_remuneracao = ['vl_remuneracao_base_mensal',
                   'vl_outro_elemento_remuneracao',
                    'vl_remuneracao_total_bruta']

# %%
def remuneracao_float(item):
    
    if pd.isnull(item):
        return np.NaN
    
    item = item.replace('R$', '')
    item = item.replace('.', '')
    item = item.replace(',', '.')
    item = item.strip()
    
    return round(float(item),2)

# %%
for col in cols_remuneracao:
    df[col] = df[col].apply(remuneracao_float)

# %% [markdown]
# Avaliar relação entre descrições dos cargos. Acho que há sobreposição entre as informações das colunas

# %%
cols_desc_cargo_base = [
    'dc_cargo_base',
    'grupo_cargo_base', 
    'nivel_cargo_base', 
    'referencia_cargo_base',
    'segmento_cargo_base'
]

# %%
df[cols_desc_cargo_base].sample(5)
# Out:
#                                     dc_cargo_base grupo_cargo_base  \
# 2029    PROFISSIONAL ENG, ARQ, AGRONOMIA,GEOLOGIA             QEAG
# 192   ANALISTA PLANEJAMENTO DESENV ORGANIZACIONAL              QAA
# 2208  ANALISTA ASSISTENCIA DESENVOLVIMENTO SOCIAL              QAA
# 2130  ANALISTA ASSISTENCIA DESENVOLVIMENTO SOCIAL              QAA
# 24      PROFISSIONAL ENG, ARQ, AGRONOMIA,GEOLOGIA             QEAG
#
#      nivel_cargo_base referencia_cargo_base segmento_cargo_base
# 2029               II                 QEAG6           AGRONOMIA
# 192                IV                   Q16  CIENCIAS CONTABEIS
# 2208                I                    Q5      SERVICO SOCIAL
# 2130               II                    Q6      SERVICO SOCIAL
# 24                 IV                QEAG17         ARQUITETURA

# %%
def remover_nivel_cargo_base(item):
    
    item = item.replace('-', '')
    
    return ''.join(char for char in item if not char.isdigit())

# %%
df['ref_cargo_base_s_nivel'] = df['referencia_cargo_base'].apply(remover_nivel_cargo_base)

# %%
pd.crosstab(df['grupo_cargo_base'],df['ref_cargo_base_s_nivel']).T
# Out:
# grupo_cargo_base        PCCS   QAA  QEAG  QPA  QPAT  QPCEL  QPDU  QPGG
# ref_cargo_base_s_nivel
# AMCI                       0     0     0    0     0      0     0    70
# APPGG                      0     0     0    0     0      0     0    64
# Q                          0  1786     0    0     0      0     0     0
# QAA                        0    47     0    0     0      0     0     0
# QCED                       0     0     0    0     0      1     0     0
# QEAG                       0     0   927    0     0      0     0     0
# QPAD                       0     0     0    1     0      0     0     0
# QPAE                       0     0     0    1     0      0     0     0
# QPAT                       0     0     0    0   488      0     0     0
# QPDE                       0     0     0    0     0      0     9     0
# S                         10     0     0    0     0      0     0     0

# %%
pd.crosstab(df['dc_cargo_base'],df['ref_cargo_base_s_nivel'])
# Out:
# ref_cargo_base_s_nivel                            AMCI  APPGG    Q  QAA  QCED  \
# dc_cargo_base
# ANALISTA                                             0      0    0   32     0
# ANALISTA ASSIST DESENV SOCIAL EQUIP SOCIAL           0      0   14    0     0
# ANALISTA ASSISTENCIA DESENVOLVIMENTO SOCIAL          0      0  793    2     0
# ANALISTA DE INFORMACOES CULTURA E DESPORTO           0      0  655   11     0
# ANALISTA DE MEIO AMBIENTE                            0      0   82    0     0
# ANALISTA DE ORDENAMENTO TERRITORIAL                  0      0   40    2     0
# ANALISTA PLANEJAMENTO DESENV ORGANIZACIONAL          0      0  202    0     0
# ANALISTA POLITICAS PUBLICAS GESTAO GOVERNAMENTAL     0     64    0    0     0
# ARQUITETO                                            0      0    0    0     0
# AUDITOR FISCAL TRIBUTARIO MUNICIPAL                  0      0    0    0     0
# AUDITOR MUNICIPAL DE CONTROLE INTERNO               70      0    0    0     0
# CONTADOR                                             0      0    0    0     0
# ECONOMISTA                                           0      0    0    0     0
# ENGENHEIRO                                           0      0    0    0     0
# ESP ADM ORÇAMENTO E FINANÇAS PÚBLICAS                0      0    0    0     0
# ESP ASSISTÊNCIA E DESENVOLVIMENTO SOCIAL             0      0    0    0     0
# ESP DESENVOLVIMENTO URBANO                           0      0    0    0     0
# ESPECIALISTA                                         0      0    0    0     0
# HISTORIADOR                                          0      0    0    0     1
# PROFISSIONAL ENG, ARQ, AGRONOMIA,GEOLOGIA            0      0    0    0     0
#
# ref_cargo_base_s_nivel                            QEAG  QPAD  QPAE  QPAT  \
# dc_cargo_base
# ANALISTA                                             0     0     0     0
# ANALISTA ASSIST DESENV SOCIAL EQUIP SOCIAL           0     0     0     0
# ANALISTA ASSISTENCIA DESENVOLVIMENTO SOCIAL          0     0     0     0
# ANALISTA DE INFORMACOES CULTURA E DESPORTO           0     0     0     0
# ANALISTA DE MEIO AMBIENTE                            0     0     0     0
# ANALISTA DE ORDENAMENTO TERRITORIAL                  0     0     0     0
# ANALISTA PLANEJAMENTO DESENV ORGANIZACIONAL          0     0     0     0
# ANALISTA POLITICAS PUBLICAS GESTAO GOVERNAMENTAL     0     0     0     0
# ARQUITETO                                            0     0     0     0
# AUDITOR FISCAL TRIBUTARIO MUNICIPAL                  0     0     0   488
# AUDITOR MUNICIPAL DE CONTROLE INTERNO                0     0     0     0
# CONTADOR                                             0     0     1     0
# ECONOMISTA                                           0     1     0     0
# ENGENHEIRO                                           0     0     0     0
# ESP ADM ORÇAMENTO E FINANÇAS PÚBLICAS                0     0     0     0
# ESP ASSISTÊNCIA E DESENVOLVIMENTO SOCIAL             0     0     0     0
# ESP DESENVOLVIMENTO URBANO                           0     0     0     0
# ESPECIALISTA                                         0     0     0     0
# HISTORIADOR                                          0     0     0     0
# PROFISSIONAL ENG, ARQ, AGRONOMIA,GEOLOGIA          927     0     0     0
#
# ref_cargo_base_s_nivel                            QPDE  S
# dc_cargo_base
# ANALISTA                                             0  0
# ANALISTA ASSIST DESENV SOCIAL EQUIP SOCIAL           0  0
# ANALISTA ASSISTENCIA DESENVOLVIMENTO SOCIAL          0  0
# ANALISTA DE INFORMACOES CULTURA E DESPORTO           0  0
# ANALISTA DE MEIO AMBIENTE                            0  0
# ANALISTA DE ORDENAMENTO TERRITORIAL                  0  0
# ANALISTA PLANEJAMENTO DESENV ORGANIZACIONAL          0  0
# ANALISTA POLITICAS PUBLICAS GESTAO GOVERNAMENTAL     0  0
# ARQUITETO                                            2  0
# AUDITOR FISCAL TRIBUTARIO MUNICIPAL                  0  0
# AUDITOR MUNICIPAL DE CONTROLE INTERNO                0  0
# CONTADOR                                             0  0
# ECONOMISTA                                           0  0
# ENGENHEIRO                                           7  0
# ESP ADM ORÇAMENTO E FINANÇAS PÚBLICAS                0  3
# ESP ASSISTÊNCIA E DESENVOLVIMENTO SOCIAL             0  1
# ESP DESENVOLVIMENTO URBANO                           0  4
# ESPECIALISTA                                         0  2
# HISTORIADOR                                          0  0
# PROFISSIONAL ENG, ARQ, AGRONOMIA,GEOLOGIA            0  0

# %% [markdown]
# Há bastante sobreposição. Vamos manter apenas a descrição do cargo e o grupo.

# %%
df.drop(['ref_cargo_base_s_nivel', 'referencia_cargo_base'], axis =1, inplace=True)

# %% [markdown]
# Parece haver uma sobreposicao parecida no que diz respeito aos cargos em comissao.
#
# Além disso, nosso conhecimento da área de negócio indica que, para os cargos em comissão, é preferível utilizar a referência.

# %%
cols_cargo_comissao = ['dc_cargo_comissao', 'referencia_cargo_comissao','escol_cargo_comissao']
df[df['dc_cargo_comissao'].notnull()][cols_cargo_comissao].sample(10)
# Out:
#                dc_cargo_comissao referencia_cargo_comissao  \
# 206   DIRETOR DE DIVISAO TECNICA                     DAS12
# 1122               COORDENADOR V                     DAS15
# 795                  COORDENADOR                     DAS10
# 518   DIRETOR DE DIVISAO TECNICA                     DAS12
# 3076        ASSESSOR ESPECIAL II                     DAS15
# 3223       SUPERVISOR TECNICO II                     DAS12
# 2780  CHEFE DE UNIDADE TECNICA I                     DAS10
# 2757  DIRETOR DE DIVISAO TECNICA                     DAS12
# 2117               COORDENADOR I                     DAS11
# 1736                 ASSESSOR II                     DAS10
#
#      escol_cargo_comissao
# 206     SUPERIOR COMPLETO
# 1122    SUPERIOR COMPLETO
# 795     SUPERIOR COMPLETO
# 518     SUPERIOR COMPLETO
# 3076        NAO SE APLICA
# 3223    SUPERIOR COMPLETO
# 2780        NAO SE APLICA
# 2757    SUPERIOR COMPLETO
# 2117    SUPERIOR COMPLETO
# 1736    SUPERIOR COMPLETO

# %%
cross_cargo_comissao = pd.crosstab(df['referencia_cargo_comissao'], df['dc_cargo_comissao'])

# %%
for col in cross_cargo_comissao:
    cross_cargo_comissao[col] = cross_cargo_comissao[col].apply(lambda x: True if x else False)

# %%
cross_cargo_comissao
# Out:
# dc_cargo_comissao          ADMINISTRADOR DE PARQUE II  ASSESSOR ESPECIAL I  \
# referencia_cargo_comissao
# DAI06                                           False                False
# DAS09                                            True                False
# DAS10                                           False                False
# DAS11                                           False                False
# DAS12                                           False                False
# DAS13                                           False                False
# DAS14                                           False                 True
# DAS15                                           False                False
# SAD                                             False                False
# SBP                                             False                False
#
# dc_cargo_comissao          ASSESSOR ESPECIAL II  ASSESSOR I  ASSESSOR II  \
# referencia_cargo_comissao
# DAI06                                     False       False        False
# DAS09                                     False        True        False
# DAS10                                     False       False         True
# DAS11                                     False       False        False
# DAS12                                     False       False        False
# DAS13                                     False       False        False
# DAS14                                     False       False        False
# DAS15                                      True       False        False
# SAD                                       False       False        False
# SBP                                       False       False        False
#
# dc_cargo_comissao          ASSESSOR TECNICO I  ASSESSOR TECNICO II  \
# referencia_cargo_comissao
# DAI06                                   False                False
# DAS09                                   False                False
# DAS10                                   False                False
# DAS11                                    True                False
# DAS12                                   False                 True
# DAS13                                   False                False
# DAS14                                   False                False
# DAS15                                   False                False
# SAD                                     False                False
# SBP                                     False                False
#
# dc_cargo_comissao          CHEFE DE ASSESSORIA TECNICA II  \
# referencia_cargo_comissao
# DAI06                                               False
# DAS09                                               False
# DAS10                                               False
# DAS11                                               False
# DAS12                                               False
# DAS13                                               False
# DAS14                                                True
# DAS15                                               False
# SAD                                                 False
# SBP                                                 False
#
# dc_cargo_comissao          CHEFE DE ASSESSORIA TECNICA III  \
# referencia_cargo_comissao
# DAI06                                                False
# DAS09                                                False
# DAS10                                                False
# DAS11                                                False
# DAS12                                                False
# DAS13                                                False
# DAS14                                                False
# DAS15                                                 True
# SAD                                                  False
# SBP                                                  False
#
# dc_cargo_comissao          CHEFE DE REPRESENTACAO FISCAL  ...  COORDENADOR V  \
# referencia_cargo_comissao                                 ...
# DAI06                                              False  ...          False
# DAS09                                              False  ...          False
# DAS10                                              False  ...          False
# DAS11                                              False  ...          False
# DAS12                                              False  ...          False
# DAS13                                               True  ...          False
# DAS14                                              False  ...          False
# DAS15                                              False  ...           True
# SAD                                                False  ...          False
# SBP                                                False  ...          False
#
# dc_cargo_comissao          DIRETOR DE DEPARTAMENTO TECNICO  \
# referencia_cargo_comissao
# DAI06                                                False
# DAS09                                                False
# DAS10                                                False
# DAS11                                                False
# DAS12                                                False
# DAS13                                                False
# DAS14                                                 True
# DAS15                                                False
# SAD                                                  False
# SBP                                                  False
#
# dc_cargo_comissao          DIRETOR DE DIVISAO TECNICA  \
# referencia_cargo_comissao
# DAI06                                           False
# DAS09                                           False
# DAS10                                           False
# DAS11                                           False
# DAS12                                            True
# DAS13                                           False
# DAS14                                           False
# DAS15                                           False
# SAD                                             False
# SBP                                             False
#
# dc_cargo_comissao          ENCARREGADO DE EQUIPE I  PRESIDENTE DE CONSELHO  \
# referencia_cargo_comissao
# DAI06                                         True                   False
# DAS09                                        False                   False
# DAS10                                        False                   False
# DAS11                                        False                   False
# DAS12                                        False                   False
# DAS13                                        False                   False
# DAS14                                        False                   False
# DAS15                                        False                    True
# SAD                                          False                   False
# SBP                                          False                   False
#
# dc_cargo_comissao          REPRESENTANTE FISCAL  SECRETARIO EXECUTIVO ADJUNTO  \
# referencia_cargo_comissao
# DAI06                                     False                         False
# DAS09                                     False                         False
# DAS10                                     False                         False
# DAS11                                     False                         False
# DAS12                                      True                         False
# DAS13                                     False                         False
# DAS14                                     False                         False
# DAS15                                     False                         False
# SAD                                       False                          True
# SBP                                       False                         False
#
# dc_cargo_comissao          SUBPREFEITO  SUBSECRETARIO  SUPERVISOR TECNICO II
# referencia_cargo_comissao
# DAI06                            False          False                  False
# DAS09                            False          False                  False
# DAS10                            False          False                  False
# DAS11                            False          False                  False
# DAS12                            False          False                   True
# DAS13                            False          False                  False
# DAS14                            False          False                  False
# DAS15                            False           True                  False
# SAD                              False          False                  False
# SBP                               True          False                  False
#
# [10 rows x 26 columns]

# %%
(cross_cargo_comissao.sum()==1).all()
# Out:
# True

# %% [markdown]
# Como não há nenhum cargo na base que corresponda a mais de uma referência, escohemos utilizar a referência do cargo, pois ela sintetiza melhor a relação entre responsabilidade e salário do que o nome do cargo.

# %%
df.drop('dc_cargo_comissao', axis=1,inplace=True)

# %% [markdown]
# Quando à escolaridade, alguns cargos em comissão podem prescindir da necessidade de ensino superior.
# No entanto, isso não afeta os vencimentos. Por isso, vamos remover essa coluna também (sobretudo porque todos os servidores de nossa base possuem ensino superior completo).

# %%
pd.crosstab(df['referencia_cargo_comissao'], df['escol_cargo_comissao'])
# Out:
# escol_cargo_comissao       ENSINO MEDIO - COMPLETO  NAO SE APLICA  \
# referencia_cargo_comissao
# ATC-1                                            0              0
# ATC-2                                            0              0
# ATC-3                                            0              0
# ATC-4                                            0              0
# DAI06                                            0              1
# DAS09                                            0             12
# DAS10                                            0             16
# DAS11                                            2              3
# DAS12                                            0              3
# DAS13                                            0              0
# DAS14                                            0              5
# DAS15                                            0             15
# SAD                                              0              1
# SBP                                              0              1
#
# escol_cargo_comissao       SUPERIOR COMPLETO
# referencia_cargo_comissao
# ATC-1                                     65
# ATC-2                                     32
# ATC-3                                      2
# ATC-4                                      5
# DAI06                                      0
# DAS09                                      6
# DAS10                                    232
# DAS11                                    145
# DAS12                                    191
# DAS13                                      1
# DAS14                                     27
# DAS15                                     21
# SAD                                        0
# SBP                                        0

# %%
df.drop('escol_cargo_comissao', axis=1,inplace=True)

# %%
df['qt_hora_jornada_semanal'].unique()
# Out:
# array(['40 H', '30 H ESP ASST SOC', '44 H', '20 H', '30 H'], dtype=object)

# %%
def jornada_int(item):
    
    item = ''.join(char for char in item if char.isdigit())
    
    return int(item)

# %%
df['qt_hora_jornada_semanal'] = df['qt_hora_jornada_semanal'].apply(jornada_int)

# %% [markdown]
# Agora vamos dropar colunas que acreditamos que não tem relação com o modelo que queremos construir, como o endereço de trabalho, o nome do servidor  etc.. Vou deixar o Regsitro Funcional para poder tirar dúvidas no portal da transparência durante a exploratória

# %%
sem_relacao = [
    'nome_servidor',
    'dc_tipo_logradouro_orgao',
    'nr_logradouro_orgao',
    'nm_logradouro_orgao',
    'tx_complemento_logradouro_orgao',
    'dc_setor' #possui muitos termos, melhro ficar só com secretaria
    
]

# %%
df.drop(sem_relacao, axis=1, inplace=True)

# %% [markdown]
# Agora vamos criar uma variável "cedido", a partir da presença de um órgão externo.

# %%
df[df['dc_orgao_externo'].notnull()][['dc_orgao_externo', 'dc_orgao']]
# Out:
#                                        dc_orgao_externo  \
# 0     TRIBUNAL DE CONTAS DO MUNICIPIO DE SAO PAULO -...
# 7                         CAMARA MUNICIPAL DE SAO PAULO
# 18                        CAMARA MUNICIPAL DE SAO PAULO
# 50                        CAMARA MUNICIPAL DE SAO PAULO
# 51                        CAMARA MUNICIPAL DE SAO PAULO
# ...                                                 ...
# 2664             AUTORIDADE MUNICIPAL DE LIMPEZA URBANA
# 2982                              HOSPITAL DAS CLINICAS
# 3045  TRIBUNAL DE CONTAS DO MUNICIPIO DE SAO PAULO -...
# 3069            FUNDACAO THEATRO MUNICIPAL DE SAO PAULO
# 3104  TRIBUNAL DE CONTAS DO MUNICIPIO DE SAO PAULO -...
#
#                                               dc_orgao
# 0                      PROCURADORIA GERAL DO MUNICIPIO
# 7     SECRETARIA MUNICIPAL DO VERDE E DO MEIO AMBIENTE
# 18                                GABINETE DO PREFEITO
# 50    SECRETARIA MUNICIPAL DO VERDE E DO MEIO AMBIENTE
# 51                   SECRETARIA MUNICIPAL DE HABITACAO
# ...                                                ...
# 2664           SECRETARIA MUNICIPAL DAS SUBPREFEITURAS
# 2982                     SECRETARIA MUNICIPAL DA SAUDE
# 3045                              GABINETE DO PREFEITO
# 3069                              GABINETE DO PREFEITO
# 3104                  CONTROLADORIA GERAL DO MUNICIPIO
#
# [108 rows x 2 columns]

# %%
df['cedido']=df['dc_orgao_externo'].notnull()

# %%
df.drop('dc_orgao_externo', axis=1, inplace=True)

# %% [markdown]
# Vamos criar uma coluna de dias de exercício. E deletar a coluna categórica de data de início de exercício.

# %%
df['dt_inicio_exercicio'] = pd.to_datetime(df['dt_inicio_exercicio'], format= '%d/%m/%Y')

# %%
df['tempo_exercicio_dias'] = (datetime.today() - df['dt_inicio_exercicio']).apply(lambda x: x.days)

# %%
df[['dt_inicio_exercicio', 'tempo_exercicio_dias']].sample(5)
# Out:
#      dt_inicio_exercicio  tempo_exercicio_dias
# 2426          2012-08-16                  3290
# 1609          2010-06-21                  4077
# 2057          2014-09-09                  2536
# 2313          2012-05-15                  3383
# 2903          2015-09-18                  2162

# %%
df.drop('dt_inicio_exercicio', axis=1, inplace=True)

# %%
df.to_csv('project_data/remuneracao_quadros_tecnicos_limpo.csv')
